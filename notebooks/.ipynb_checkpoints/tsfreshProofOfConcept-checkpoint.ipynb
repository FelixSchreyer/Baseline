# %% [markdown]
# # Pipeline using Tsfresh and Adapt
# Creation of the pipeline for the classical ML model

# %%
# %matplotlib inline

import matplotlib.pylab as plt

import tsfresh
from tsfresh.utilities.dataframe_functions import roll_time_series
from tsfresh import extract_features, select_features
from tsfresh.utilities.dataframe_functions import impute

from sklearn.metrics import classification_report
from adapt.feature_based import FA
from sklearn.ensemble import RandomForestClassifier

import pandas as pd
import os
from my_package.add_columns import create_time_column, create_id_column, create_rul_columns

# %% [markdown]
# ## Load Data
# In this case we use a failure dataset of robots -> Need to exchange is for our data later

# %%
# # Cleans Dataframe by removing the separate columns for hour, minute, 
# # second and millisecond and replacing them by a singe datetime column
# def create_time_column(df_time):
#     datetime.time()
#     custom_header_names = ['hour', 'minute', 'second', 'milisecond', 'x', 'y']
#     
#     df_time.columns.name = 'column_names'
#     df_time.columns = custom_header_names
#     default_year = 2023
#     default_month = 1
#     default_day = 1
# 
#     df_time.reset_index(drop=True)
# 
#     # Create a new datetime column
#     df_time['time_column'] = pd.to_datetime({
#         'year': default_year,
#         'month': default_month,
#         'day': default_day,
#         'hour': df_time['hour'],
#         'minute': df_time['minute'],
#         'second': df_time['second'],
#         'millisecond': df_time['milisecond']
#     })
#     columns_to_drop = ['hour', 'minute', 'second', 'milisecond']
#     df_time = df_time.drop(columns=columns_to_drop)
#     
#     new_column_order = ['time_column', 'x', 'y']
#     df_time = df_time[new_column_order]
#     
#     return df_time
# 
# # Iterates through dataframe to add a RUL for every row
# def create_rul_columns(df_rul):
#     df_rul['RUL'] = df_rul.apply(remaining_useful_lifetime, axis=1)
#     df_rul['integer_column'] = df_rul['RUL'].apply(map_to_integer)
#     return df_rul
# 
# # Calculates RUL by computing time difference between last sensor values and input entry
# def remaining_useful_lifetime(df_rul):
#     current = df_rul['id'][1]
#     beginning = combined_df['time_column'].min()
#     failure = combined_df['time_column'].max()
#     dateTimeDifference = failure - current
#     dateTimeDifferenceInMinutes = dateTimeDifference.total_seconds() / 60
#     result = ((failure-current)/(failure-beginning))
#     return result
# 
# def map_to_integer(value):
#     return int(value * 5)
# 
# def add_id_column(df, value):
#     df['id'] = value
#     return df

# %%
# Directory containing CSV files
csv_directory = '../FEMTO/Bearing1_1/'

# List to store DataFrames from each CSV
dataframes = []

# Loop through each file in the directory
for filename in os.listdir(csv_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(csv_directory, filename)
        df = pd.read_csv(file_path, header=None, skiprows=lambda x: x % 375)
        dataframes.append(df)

# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
# Add Time Column, RUL columns and ID Column
combined_df = create_time_column(combined_df)
#combined_df = create_rul_columns(combined_df)
#combined_df = create_id_column(combined_df, "1")
#combined_df = combined_df.sort_values(by='time_column')
#combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#                          time        x      y
# 0     2023-01-01 14:46:34.664   -0.315  0.616
# 1     2023-01-01 14:46:49.312   -0.074 -0.800
# 2     2023-01-01 14:47:03.960    0.207  0.753
# 3     2023-01-01 14:47:18.610    1.091  0.089
# 4     2023-01-01 14:47:33.260   -3.090  0.033
# ...                       ...      ...    ...
# 20548 2023-01-01 16:38:22.550    0.444  0.333
# 20549 2023-01-01 17:02:47.005  153.220    NaN
# 20550 2023-01-01 17:03:25.000  152.530    NaN
# 20551 2023-01-01 15:04:47.005  125.440    NaN
# 20552 2023-01-01 15:05:25.000  125.360    NaN
#
# [20553 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(combined_df['time_column'], combined_df['x'], label='X')
plt.plot(combined_df['time_column'], combined_df['y'], label='Y')
plt.xlabel('Time')
plt.ylabel('X/Y')
plt.title('Time Series Plot')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create rolled dataframe with at least 1000 observations
df_rolled = roll_time_series(combined_df, column_id='id', column_sort="time_column", 
                             min_timeshift=1000, rolling_direction=200)
df_rolled
# Out:
# /Users/felixschreyer/anaconda3/envs/Testing/lib/python3.11/site-packages/tsfresh/utilities/dataframe_functions.py:520: UserWarning: Your time stamps are not uniformly sampled, which makes rolling nonsensical in some domains.
#   warnings.warn(
# Rolling: 100%|██████████| 20/20 [00:07<00:00,  2.51it/s]
#                     time_column       x      y  \
# 0       2023-01-01 09:40:44.664   0.552 -0.146
# 1       2023-01-01 09:40:47.005  70.378    NaN
# 2       2023-01-01 09:40:51.499   0.644  0.516
# 3       2023-01-01 09:40:54.664  -0.140 -0.043
# 4       2023-01-01 09:40:58.335  -0.027 -0.100
# ...                         ...     ...    ...
# 4839215 2023-01-01 17:29:03.530   3.183  4.889
# 4839216 2023-01-01 17:29:06.700  -6.517  2.857
# 4839217 2023-01-01 17:29:10.370   1.040 -2.746
# 4839218 2023-01-01 17:29:13.530   1.528 -1.618
# 4839219 2023-01-01 17:29:20.370  -4.354 -2.291
#
#                                       id
# 0        (1, 2023-01-01 09:53:11.660000)
# 1        (1, 2023-01-01 09:53:11.660000)
# 2        (1, 2023-01-01 09:53:11.660000)
# 3        (1, 2023-01-01 09:53:11.660000)
# 4        (1, 2023-01-01 09:53:11.660000)
# ...                                  ...
# 4839215  (1, 2023-01-01 17:29:20.370000)
# 4839216  (1, 2023-01-01 17:29:20.370000)
# 4839217  (1, 2023-01-01 17:29:20.370000)
# 4839218  (1, 2023-01-01 17:29:20.370000)
# 4839219  (1, 2023-01-01 17:29:20.370000)
#
# [4839220 rows x 4 columns]

# %%
df_rolled = create_rul_columns(df_rolled)
df_rolled
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_rolled = create_rul_columns(df_rolled)
#       2 df_rolled
#
# Cell In[2], line 37, in create_rul_columns(df_rul)
#      36 def create_rul_columns(df_rul):
# ---> 37     df_rul['RUL'] = df_rul.apply(remaining_useful_lifetime, axis=1)
#      38     df_rul['integer_column'] = df_rul['RUL'].apply(map_to_integer)
#      39     return df_rul
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 44, in remaining_useful_lifetime(df_rul)
#      42 def remaining_useful_lifetime(df_rul):
#      43     current = df_rul['id'][1]
# ---> 44     beginning = combined_df['time_column'].min()
#      45     failure = combined_df['time_column'].max()
#      46     dateTimeDifference = failure - current
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/generic.py:11965, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11945 @doc(
#   11946     _num_doc,
#   11947     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11963     **kwargs,
#   11964 ):
# > 11965     return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/generic.py:11365, in NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11357 def min(
#   11358     self,
#   11359     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11363     **kwargs,
#   11364 ):
# > 11365     return self._stat_function(
#   11366         "min",
#   11367         nanops.nanmin,
#   11368         axis,
#   11369         skipna,
#   11370         level,
#   11371         numeric_only,
#   11372         **kwargs,
#   11373     )
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/series.py:4797, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4793     self._get_axis_number(axis)
#    4795 if isinstance(delegate, ExtensionArray):
#    4796     # dispatch to ExtensionArray interface
# -> 4797     return delegate._reduce(name, skipna=skipna, **kwds)
#    4799 else:
#    4800     # dispatch to numpy arrays
#    4801     if numeric_only and not is_numeric_dtype(self.dtype):
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/arrays/base.py:1439, in ExtensionArray._reduce(self, name, skipna, **kwargs)
#    1434 if meth is None:
#    1435     raise TypeError(
#    1436         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1437         f"does not support reduction '{name}'"
#    1438     )
# -> 1439 return meth(skipna=skipna, **kwargs)
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:1625, in DatetimeLikeArrayMixin.min(self, axis, skipna, **kwargs)
#    1622         return self._box_func(result)
#    1623     return self._from_backing_data(result)
# -> 1625 result = nanops.nanmin(self._ndarray, axis=axis, skipna=skipna)
#    1626 return self._wrap_reduction_result(axis, result)
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/nanops.py:1053, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1050 else:
#    1051     result = getattr(values, meth)(axis)
# -> 1053 result = _maybe_null_out(result, axis, mask, values.shape)
#    1054 return result
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/nanops.py:1486, in _maybe_null_out(result, axis, mask, shape, min_count)
#    1484             result[null_mask] = None
#    1485 elif result is not NaT:
# -> 1486     if check_below_min_count(shape, mask, min_count):
#    1487         result = np.nan
#    1489 return result
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/pandas/core/nanops.py:1517, in check_below_min_count(shape, mask, min_count)
#    1515     non_nulls = np.prod(shape)
#    1516 else:
# -> 1517     non_nulls = mask.size - mask.sum()
#    1518 if non_nulls < min_count:
#    1519     return True
#
# File ~/anaconda3/envs/Testing/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
df_rolled['y'] = df_rolled['y'].fillna(method='ffill')

# %%
# Create features based upon rolled dataframe
X = extract_features(df_rolled.drop(columns=["RUL", "integer_column"]), column_id='id', column_sort='time_column', 
                     column_kind=None, column_value=None,
                     default_fc_parameters= tsfresh.feature_extraction.MinimalFCParameters(),
                     # we impute = remove all NaN features automatically
                     impute_function=impute)
X.head()
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:00<00:00, 20.66it/s]
#                            x__sum_values  x__median   x__mean  x__length  \
# 1 2023-01-01 09:53:11.660       4422.453     0.0160  3.991384     1108.0
#   2023-01-01 09:55:01.499       5109.587     0.0145  3.906412     1308.0
#   2023-01-01 09:57:08.843       6002.456     0.0165  3.980408     1508.0
#   2023-01-01 09:59:16.190       6807.508     0.0155  3.985660     1708.0
#   2023-01-01 10:01:23.530       7723.231     0.0195  4.047815     1908.0
#
#                            x__standard_deviation  x__variance  \
# 1 2023-01-01 09:53:11.660              18.480368   341.523995
#   2023-01-01 09:55:01.499              18.417202   339.193312
#   2023-01-01 09:57:08.843              18.731049   350.852199
#   2023-01-01 09:59:16.190              18.851029   355.361289
#   2023-01-01 10:01:23.530              19.101828   364.879820
#
#                            x__root_mean_square  x__maximum  \
# 1 2023-01-01 09:53:11.660            18.906484      97.063
#   2023-01-01 09:55:01.499            18.826932      98.835
#   2023-01-01 09:57:08.843            19.149304     100.130
#   2023-01-01 09:59:16.190            19.267765     101.010
#   2023-01-01 10:01:23.530            19.525999     102.480
#
#                            x__absolute_maximum  x__minimum  y__sum_values  \
# 1 2023-01-01 09:53:11.660               97.063      -2.031         -9.285
#   2023-01-01 09:55:01.499               98.835      -2.031         -4.407
#   2023-01-01 09:57:08.843              100.130      -2.031         -3.739
#   2023-01-01 09:59:16.190              101.010      -2.031          9.336
#   2023-01-01 10:01:23.530              102.480      -2.031          4.206
#
#                            y__median   y__mean  y__length  \
# 1 2023-01-01 09:53:11.660    -0.0200 -0.008380     1108.0
#   2023-01-01 09:55:01.499    -0.0200 -0.003369     1308.0
#   2023-01-01 09:57:08.843    -0.0120 -0.002479     1508.0
#   2023-01-01 09:59:16.190    -0.0005  0.005466     1708.0
#   2023-01-01 10:01:23.530    -0.0045  0.002204     1908.0
#
#                            y__standard_deviation  y__variance  \
# 1 2023-01-01 09:53:11.660               0.462740     0.214128
#   2023-01-01 09:55:01.499               0.459124     0.210794
#   2023-01-01 09:57:08.843               0.455420     0.207407
#   2023-01-01 09:59:16.190               0.451683     0.204018
#   2023-01-01 10:01:23.530               0.453850     0.205980
#
#                            y__root_mean_square  y__maximum  \
# 1 2023-01-01 09:53:11.660             0.462816       1.567
#   2023-01-01 09:55:01.499             0.459136       1.567
#   2023-01-01 09:57:08.843             0.455427       1.567
#   2023-01-01 09:59:16.190             0.451716       1.649
#   2023-01-01 10:01:23.530             0.453855       1.649
#
#                            y__absolute_maximum  y__minimum
# 1 2023-01-01 09:53:11.660                1.567      -1.468
#   2023-01-01 09:55:01.499                1.567      -1.468
#   2023-01-01 09:57:08.843                1.567      -1.468
#   2023-01-01 09:59:16.190                1.649      -1.468
#   2023-01-01 10:01:23.530                1.649      -1.468

# %%
combined_y=df_rolled['integer_column']
combined_y.index = df_rolled['id'].tolist()

distinct_entries_series = combined_y.groupby(level=0).first()
distinct_entries_series
# Out:
# (1, 2023-01-01 09:53:11.660000)    4
# (1, 2023-01-01 09:55:01.499000)    4
# (1, 2023-01-01 09:57:08.843000)    4
# (1, 2023-01-01 09:59:16.190000)    4
# (1, 2023-01-01 10:01:23.530000)    4
#                                   ..
# (1, 2023-01-01 17:20:01.499000)    0
# (1, 2023-01-01 17:22:08.843000)    0
# (1, 2023-01-01 17:24:16.190000)    0
# (1, 2023-01-01 17:26:23.530000)    0
# (1, 2023-01-01 17:29:20.370000)    0
# Name: integer_column, Length: 215, dtype: int64

# %%
X_train_selected = select_features(X, distinct_entries_series)
X_train_selected
# Out:
#                            y__minimum  y__absolute_maximum  y__length  \
# 1 2023-01-01 09:53:11.660      -1.468                1.567     1108.0
#   2023-01-01 09:55:01.499      -1.468                1.567     1308.0
#   2023-01-01 09:57:08.843      -1.468                1.567     1508.0
#   2023-01-01 09:59:16.190      -1.468                1.649     1708.0
#   2023-01-01 10:01:23.530      -1.468                1.649     1908.0
# ...                               ...                  ...        ...
#   2023-01-01 17:20:01.499      -7.926                7.926    43108.0
#   2023-01-01 17:22:08.843      -7.926                7.926    43308.0
#   2023-01-01 17:24:16.190      -7.926                7.926    43508.0
#   2023-01-01 17:26:23.530      -7.926                8.447    43708.0
#   2023-01-01 17:29:20.370      -7.926                9.944    43908.0
#
#                            x__root_mean_square  x__variance  x__sum_values  \
# 1 2023-01-01 09:53:11.660            18.906484   341.523995       4422.453
#   2023-01-01 09:55:01.499            18.826932   339.193312       5109.587
#   2023-01-01 09:57:08.843            19.149304   350.852199       6002.456
#   2023-01-01 09:59:16.190            19.267765   355.361289       6807.508
#   2023-01-01 10:01:23.530            19.525999   364.879820       7723.231
# ...                                        ...          ...            ...
#   2023-01-01 17:20:01.499            25.391079   617.501753     224844.969
#   2023-01-01 17:22:08.843            25.434108   619.596407     226271.197
#   2023-01-01 17:24:16.190            25.469894   621.364708     227538.042
#   2023-01-01 17:26:23.530            25.518800   623.750864     229032.787
#   2023-01-01 17:29:20.370            25.462105   621.114907     229012.354
#
#                            x__length   x__mean  x__standard_deviation  \
# 1 2023-01-01 09:53:11.660     1108.0  3.991384              18.480368
#   2023-01-01 09:55:01.499     1308.0  3.906412              18.417202
#   2023-01-01 09:57:08.843     1508.0  3.980408              18.731049
#   2023-01-01 09:59:16.190     1708.0  3.985660              18.851029
#   2023-01-01 10:01:23.530     1908.0  4.047815              19.101828
# ...                              ...       ...                    ...
#   2023-01-01 17:20:01.499    43108.0  5.215852              24.849583
#   2023-01-01 17:22:08.843    43308.0  5.224697              24.891694
#   2023-01-01 17:24:16.190    43508.0  5.229798              24.927188
#   2023-01-01 17:26:23.530    43708.0  5.240066              24.975005
#   2023-01-01 17:29:20.370    43908.0  5.215732              24.922177
#
#                            x__maximum  x__absolute_maximum  \
# 1 2023-01-01 09:53:11.660      97.063               97.063
#   2023-01-01 09:55:01.499      98.835               98.835
#   2023-01-01 09:57:08.843     100.130              100.130
#   2023-01-01 09:59:16.190     101.010              101.010
#   2023-01-01 10:01:23.530     102.480              102.480
# ...                               ...                  ...
#   2023-01-01 17:20:01.499     156.340              156.340
#   2023-01-01 17:22:08.843     158.280              158.280
#   2023-01-01 17:24:16.190     161.170              161.170
#   2023-01-01 17:26:23.530     163.620              163.620
#   2023-01-01 17:29:20.370     163.620              163.620
#
#                            y__standard_deviation  y__variance  \
# 1 2023-01-01 09:53:11.660               0.462740     0.214128
#   2023-01-01 09:55:01.499               0.459124     0.210794
#   2023-01-01 09:57:08.843               0.455420     0.207407
#   2023-01-01 09:59:16.190               0.451683     0.204018
#   2023-01-01 10:01:23.530               0.453850     0.205980
# ...                                          ...          ...
#   2023-01-01 17:20:01.499               0.449903     0.202413
#   2023-01-01 17:22:08.843               0.458101     0.209856
#   2023-01-01 17:24:16.190               0.476865     0.227400
#   2023-01-01 17:26:23.530               0.500713     0.250713
#   2023-01-01 17:29:20.370               0.543237     0.295107
#
#                            y__root_mean_square  y__maximum  y__sum_values  \
# 1 2023-01-01 09:53:11.660             0.462816       1.567         -9.285
#   2023-01-01 09:55:01.499             0.459136       1.567         -4.407
#   2023-01-01 09:57:08.843             0.455427       1.567         -3.739
#   2023-01-01 09:59:16.190             0.451716       1.649          9.336
#   2023-01-01 10:01:23.530             0.453855       1.649          4.206
# ...                                        ...         ...            ...
#   2023-01-01 17:20:01.499             0.449910       4.090       -110.973
#   2023-01-01 17:22:08.843             0.458106       4.414        -96.981
#   2023-01-01 17:24:16.190             0.476872       5.772       -115.741
#   2023-01-01 17:26:23.530             0.500715       8.447        -59.695
#   2023-01-01 17:29:20.370             0.543238       9.944        -27.539
#
#                            x__minimum  y__median  x__median   y__mean
# 1 2023-01-01 09:53:11.660      -2.031    -0.0200     0.0160 -0.008380
#   2023-01-01 09:55:01.499      -2.031    -0.0200     0.0145 -0.003369
#   2023-01-01 09:57:08.843      -2.031    -0.0120     0.0165 -0.002479
#   2023-01-01 09:59:16.190      -2.031    -0.0005     0.0155  0.005466
#   2023-01-01 10:01:23.530      -2.031    -0.0045     0.0195  0.002204
# ...                               ...        ...        ...       ...
#   2023-01-01 17:20:01.499     -12.404    -0.0030     0.0320 -0.002574
#   2023-01-01 17:22:08.843     -12.404    -0.0020     0.0320 -0.002239
#   2023-01-01 17:24:16.190     -18.852    -0.0020     0.0320 -0.002660
#   2023-01-01 17:26:23.530     -19.171    -0.0020     0.0320 -0.001366
#   2023-01-01 17:29:20.370     -19.171    -0.0020     0.0330 -0.000627
#
# [215 rows x 20 columns]

# %% [markdown]
# ## Begin of FA and Model Training

# %%
Xs = X_train_selected
Xt = X_train_selected
ys = distinct_entries_series
yt = distinct_entries_series

# %%
model = FA(RandomForestClassifier(), Xt=Xt[:10], yt=yt[:10], random_state=0)

# %%
model.fit(Xs, ys)


model.score(Xt, yt)
print(classification_report(yt, model.predict(Xt)))
# Out:
# Fit transform...
# Previous shape: (215, 20)
# New shape: (225, 60)
# Fit Estimator...
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        44
#            1       0.00      0.00      0.00        44
#            2       0.00      0.00      0.00        44
#            3       0.98      0.98      0.98        44
#            4       0.23      1.00      0.37        39
#
#     accuracy                           0.38       215
#    macro avg       0.24      0.40      0.27       215
# weighted avg       0.24      0.38      0.27       215
# /Users/felixschreyer/anaconda3/envs/Testing/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/felixschreyer/anaconda3/envs/Testing/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/felixschreyer/anaconda3/envs/Testing/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
